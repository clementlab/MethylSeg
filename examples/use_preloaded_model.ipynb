# %%
import sys

import numpy as np
import pandas as pd
import yaml
from pathlib import Path

import os


from methylseg import MethylSegPathway, MethylDataPrep, MethylStateAssignmentMethod, MethylationStates

# %%
ip = get_ipython()
path = None
if "__vsc_ipynb_file__" in ip.user_ns:
    path = ip.user_ns["__vsc_ipynb_file__"]

currfile = os.path.splitext(os.path.basename(path))[0]

METHYL_SEG_PATH_PARENT = Path(currfile).resolve().parent.parent
DATA_DIR = METHYL_SEG_PATH_PARENT / Path("data")
REFERENCE_DIR = DATA_DIR / Path("reference_files")

# %%
model = MethylSegPathway.get_pretrained_model("test_data")
